# %% [markdown]
# #### Imports

# %%
import os
import skimage.io
import skimage.morphology
import skimage.segmentation
import numpy as np

# %%
from skimage.transform import resize
import matplotlib.pyplot as plt

# %% [markdown]
# ### Convert manually annotated to boundary labels and save

# %%
sorted(os.listdir('/home/fvitez/nuclei_detection/manually_annotated_images/malou/SegmentationClass/'))
# Out:
# ['MFGTMPcx7_170702000001_G07f02d0.png',
#  'MFGTMPcx7_170702090001_B22f15d0.png',
#  'MFGTMPcx7_170702090001_N06f14d0.png',
#  'MFGTMPcx7_170731090001_K24f10d0.png',
#  'MFGTMPcx7_170801050001_A01f03d0.png']

# %% [markdown]
# #### Malous manually annotated images

# %%
filelist = sorted(os.listdir('/home/fvitez/nuclei_detection/manually_annotated_images/malou/SegmentationClass/'))
#try:
#    filelist.remove('.ipynb_checkpoints')

image_names = [os.path.join('/home/fvitez/nuclei_detection/manually_annotated_images/malou/SegmentationClass/', f) for f in filelist]

# %%
imagebuffer = skimage.io.imread_collection(image_names)
images = imagebuffer.concatenate()

# %%
#folder_list = sorted(os.listdir('/home/fvitez/nuclei_detection/aitslab_boundary_labels/'))
#folder_list.remove('ipynb_checkpoints')



labels_dir = '/home/fvitez/nuclei_detection/aitslab_boundary_labels/'
annot_dir = 'home/fvitez_nuclei_detection/aitslab_annotations/'

for n,i in enumerate(images):

    # strip the first channel
    if len(i.shape) == 3:
        i = i[:,:,0]
    
    annot = skimage.morphology.label(i) # convert to annotation
    
    
    break
    boundaries = skimage.segmentation.find_boundaries(annot) #extract boundaries
    
    for k in range(2, 2, 2):
        boundaries = skimage.morphology.binary_dilation(boundaries)
    
    # prepare buffer for binary label
    label_binary = np.zeros((annot.shape + (3,)))

    # write binary label
    label_binary[(annot == 0) & (boundaries == 0), 0] = 1
    label_binary[(annot != 0) & (boundaries == 0), 1] = 1
    label_binary[boundaries == 1, 2] = 1
    
    # save it - converts image to range from 0 to 255
    skimage.io.imsave(labels_dir + filelist[n][:-13] + '/' + filelist[n], label_binary)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# #### Filips annotated images

# %% [markdown]
# ##### first round

# %%
filelist = sorted(os.listdir('/home/fvitez/nuclei_detection/manually_annotated_images/9_MFGTMPcx7_170803210001_1104x1104_sharp/SegmentationClass/'))
image_names = [os.path.join('/home/fvitez/nuclei_detection/manually_annotated_images/9_MFGTMPcx7_170803210001_1104x1104_sharp/SegmentationClass/', f) for f in filelist]

imagebuffer = skimage.io.imread_collection(image_names)
images = imagebuffer.concatenate()

# %%
#folder_list = sorted(os.listdir('/home/fvitez/nuclei_detection/aitslab_boundary_labels/'))
#folder_list.remove('ipynb_checkpoints')



labels_dir = '/home/fvitez/nuclei_detection/aitslab_boundary_labels/'


for n,i in enumerate(images):

    # strip the first channel
    if len(i.shape) == 3:
        i = i[:,:,0]
    
    annot = skimage.morphology.label(i) # convert to annotation
    boundaries = skimage.segmentation.find_boundaries(annot) #extract boundaries
    
    for k in range(2, 2, 2):
        boundaries = skimage.morphology.binary_dilation(boundaries)
    
    # prepare buffer for binary label
    label_binary = np.zeros((annot.shape + (3,)))

    # write binary label
    label_binary[(annot == 0) & (boundaries == 0), 0] = 1
    label_binary[(annot != 0) & (boundaries == 0), 1] = 1
    label_binary[boundaries == 1, 2] = 1
    
    # save it - converts image to range from 0 to 255
    skimage.io.imsave(labels_dir + filelist[n][:-13] + '/' + filelist[n], label_binary)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# ##### Second round

# %%
filelist = sorted(os.listdir('/home/fvitez/nuclei_detection/manually_annotated_images/9_MFGTMPcx7_170803210001_1104x1104/SegmentationClass/'))
image_names = [os.path.join('/home/fvitez/nuclei_detection/manually_annotated_images/9_MFGTMPcx7_170803210001_1104x1104/SegmentationClass/', f) for f in filelist]

imagebuffer = skimage.io.imread_collection(image_names)
images = imagebuffer.concatenate()

# %%
#folder_list = sorted(os.listdir('/home/fvitez/nuclei_detection/aitslab_boundary_labels/'))
#folder_list.remove('ipynb_checkpoints')



labels_dir = '/home/fvitez/nuclei_detection/aitslab_boundary_labels/'


for n,i in enumerate(images):

    # strip the first channel
    if len(i.shape) == 3:
        i = i[:,:,0]
    
    annot = skimage.morphology.label(i) # convert to annotation
    boundaries = skimage.segmentation.find_boundaries(annot) #extract boundaries
    
    for k in range(2, 2, 2):
        boundaries = skimage.morphology.binary_dilation(boundaries)
    
    # prepare buffer for binary label
    label_binary = np.zeros((annot.shape + (3,)))

    # write binary label
    label_binary[(annot == 0) & (boundaries == 0), 0] = 1
    label_binary[(annot != 0) & (boundaries == 0), 1] = 1
    label_binary[boundaries == 1, 2] = 1
    
    # save it - converts image to range from 0 to 255
    skimage.io.imsave(labels_dir + "all_images" + '/' + filelist[n], label_binary)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# #### Resize and save

# %%
filelist = sorted(os.listdir('/home/fvitez/nuclei_detection/aitslab_boundary_labels/all_images/'))
image_names = [os.path.join('/home/fvitez/nuclei_detection/aitslab_boundary_labels/all_images/', f) for f in filelist]

imagebuffer = skimage.io.imread_collection(image_names)
images = imagebuffer.concatenate()

# %%
for n,i in enumerate(images):
    i = resize(i, (520, 696), mode='constant', preserve_range=True)
    #plt.imshow(i)
    #break
    skimage.io.imsave('/home/fvitez/nuclei_detection/aitslab_boundary_labels/resized_images/' + filelist[n], i)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
