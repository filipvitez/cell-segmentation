# %% [markdown]
# > In this notebook, otsus method will be compared with model 1 (broad institute model) and model 3 (10 different versions with 1 image left out of training for testing)
# >
# > First, the models will predict on the images, then the results will be evaluated visually and using IoU and F1 score

# %% [markdown]
# #### Imports

# %%
import sys
import os
import os.path

import numpy as np
import skimage.io
import glob

import shutil
#from config import config_vars

from tqdm import tqdm
import pandas as pd

import matplotlib.pyplot as plt
import skimage.morphology

import tensorflow as tf
import keras

import utils.metrics
import utils.model_builder
from skimage.transform import resize
# Out:
# Using TensorFlow backend.

# %%
import utils.evaluation

# %% [markdown]
# #### Functions

# %%
# Display prediction along with segmentation to visualize errors

def show(ground_truth, prediction, threshold=0.5, image_name="N"):
    
    # Compute Intersection over Union
    IOU = utils.evaluation.intersection_over_union(ground_truth, prediction)
    
    # Create diff map
    diff = np.zeros(ground_truth.shape + (3,))
    A = ground_truth.copy()
    B = prediction.copy()
    A[A > 0] = 1
    B[B > 0] = 1
    D = A - B
    #diff[D > 0,:2] = 1
    #diff[D < 0,1:] = 1
    
    # Object-level errors
    C = IOU.copy()
    C[C>=threshold] = 1
    C[C<threshold] = 0
    missed = np.where(np.sum(C,axis=1) == 0)[0]
    extra = np.where(np.sum(C,axis=0) == 0)[0]

    for m in missed:
        diff[ground_truth == m+1, 0] = 1
    for e in extra:
        diff[prediction == e+1, 2] = 1
    
    # Display figures
    fig, ax = plt.subplots(1, 4, figsize=(18,6))
    ax[0].imshow(ground_truth)
    ax[0].set_title("True objects:"+str(len(np.unique(ground_truth))))
    ax[1].imshow(diff)
    ax[1].set_title("Segmentation errors:"+str(len(missed)))
    ax[2].imshow(prediction)
    ax[2].set_title("Predicted objects:"+str(len(np.unique(prediction))))
    ax[3].imshow(IOU)
    ax[3].set_title(image_name)

# %%
config_vars = {
    'object_dilation': 3
}

# %% [markdown]
# ### Otsu's method (baseline)

# %% [markdown]
# #### load images

# %% [markdown]
# ###### ground truth

# %%
filename = sorted(os.listdir('/home/fvitez/nuclei_detection/aitslab_boundary_labels/resized_images/'))
image_names = [os.path.join('/home/fvitez/nuclei_detection/resized_aitslab_png_images/', f) for f in filename]

# %%
gt = sorted(os.listdir('/home/fvitez/nuclei_detection/manually_annotated_images/malou/SegmentationClass/'))

# %%
sorted(os.listdir('/home/fvitez/nuclei_detection/manually_annotated_images/malou/SegmentationClass/'))
# Out:
# ['MFGTMPcx7_170702000001_G07f02d0.png',
#  'MFGTMPcx7_170702090001_B22f15d0.png',
#  'MFGTMPcx7_170702090001_N06f14d0.png',
#  'MFGTMPcx7_170731090001_K24f10d0.png',
#  'MFGTMPcx7_170801050001_A01f03d0.png']

# %%
gt = '/home/fvitez/nuclei_detection/manually_annotated_images/malou/SegmentationClass/' + gt[0]

# %%
gt = skimage.io.imread(gt)

# %%
plt.imshow(gt)

# %%
gt = skimage.morphology.label(gt)

# %%
gt = resize(gt, (520, 696), mode='constant', preserve_range=True)

# %%
plt.imshow(gt)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
if len(gt.shape) == 3:
    plt.imshow(gt[:,:,0])

# %%
ots.shape
# Out:
# (520, 696)

# %% [markdown]
# ##### otsus predictions

# %%
filename = sorted(os.listdir('/home/fvitez/nuclei_detection/aitslab_boundary_labels/resized_images/'))
image_names = [os.path.join('/home/fvitez/nuclei_detection/otsus_prediction/annotation/', f) for f in filename]

# %%
ots = image_names[0]

# %%
ots = skimage.io.imread(ots)

# %%
plt.imshow(ots)

# %%
filename = sorted(os.listdir('/home/fvitez/nuclei_detection/aitslab_boundary_labels/resized_images/'))
image_names = [os.path.join('/home/fvitez/nuclei_detection/otsus_prediction/labels/', f) for f in filename]

# %%
ots = image_names[0]

# %%
ots
# Out:
# '/home/fvitez/nuclei_detection/otsus_prediction/labels/MFGTMPcx7_170702000001_G07f02d0.png'

# %%
ots = skimage.io.imread(ots)

# %%
plt.imshow(ots)

# %%
# Out:
# array([[255,   0,   0],
#        [255,   0,   0],
#        [255,   0,   0],
#        ...,
#        [255,   0,   0],
#        [255,   0,   0],
#        [255,   0,   0]], dtype=uint8)

# %%
filename = sorted(os.listdir('/home/fvitez/nuclei_detection/aitslab_boundary_labels/resized_images/'))
image_names = [os.path.join('/home/fvitez/nuclei_detection/resized_aitslab_png_images/', f) for f in filename]
images = skimage.io.imread_collection(image_names)

# %%
#images = images.concatenate()
im = images[0]
thresh_val = skimage.filters.threshold_otsu(im) #find threshold using otsus method
mask = im > thresh_val # create mask 
object_labels = skimage.measure.label(mask) # convert to skimage label
#annot = skimage.morphology.label(mask) # convert to annotation

# %%
plt.imshow(object_labels)

# %%
object_labels = np.asarray([object_labels,object_labels])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-3eea0d9bec55> in <module>
# ----> 1 object_labels = np.asarray([object_labels,object_labels],(1,2))
#
# ~/.conda/envs/nuclei_detection/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# TypeError: data type not understood

# %%
ots.shape
# Out:
# (520, 696, 3)

# %%
object_labels.shape
# Out:
# (2, 520, 696)

# %%
#all_images = filename
image_name = 'MFGTMPcx7_170702000001_G07f02d0.png'

results = pd.DataFrame(columns=["Image", "Threshold", "F1", "Jaccard", "TP", "FP", "FN"])
false_negatives = pd.DataFrame(columns=["False_Negative", "Area"])
splits_merges = pd.DataFrame(columns=["Image_Name", "Merges", "Splits"])

#for image_name in all_images:
    # Load ground truth data
    

#img_filename = os.path.join('/home/jupyter/aitslab_images/raw_annotations/', image_name)
#ground_truth = skimage.io.imread(img_filename)
#ground_truth = skimage.morphology.label(ground_truth)
#ground_truth = resize(ground_truth, (520, 696), mode='constant', preserve_range=True)

#if len(ground_truth.shape) == 3:
#    ground_truth = ground_truth[:,:,0]

# Transform to label matrix
#ground_truth = skimage.morphology.label(ground_truth)
#ground_truth = skimage.morphology.label(ground_truth)

# Load predictions
#pred_filename = os.path.join(config_vars["labels_out_dir"], image_name)
#prediction = skimage.io.imread(pred_filename.replace(".png",".tif"))
ground_truth = gt
prediction = label_binary

# Apply object dilation
if config_vars["object_dilation"] > 0:
    struct = skimage.morphology.square(config_vars["object_dilation"])
    prediction = skimage.morphology.dilation(prediction, struct)
elif config_vars["object_dilation"] < 0:
    struct = skimage.morphology.square(-config_vars["object_dilation"])
    prediction = skimage.morphology.erosion(prediction, struct)

# Relabel objects (cut margin of 30 pixels to make a fair comparison with DeepCell)
#ground_truth = skimage.segmentation.relabel_sequential(ground_truth)[0] #[30:-30,30:-30])[0]
#prediction = skimage.segmentation.relabel_sequential(prediction)[0] #[30:-30,30:-30])[0]

# Compute evaluation metrics
results = utils.evaluation.compute_af1_results(
    ground_truth, 
    prediction, 
    results, 
    image_name
)

false_negatives = utils.evaluation.get_false_negatives(
    ground_truth, 
    prediction, 
    false_negatives, 
    image_name
)

splits_merges = utils.evaluation.get_splits_and_merges(
    ground_truth, 
    prediction, 
    splits_merges, 
    image_name
)

# Display an example image
#if image_name == all_images[5]:
show(ground_truth, prediction, image_name=image_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-aeb35f92d1ca> in <module>
#      45     prediction,
#      46     results,
# ---> 47     image_name
#      48 )
#      49
#
# ~/nuclei_detection/utils/evaluation.py in compute_af1_results(ground_truth, prediction, results, image_name)
#      57
#      58     # Compute IoU
# ---> 59     IOU = intersection_over_union(ground_truth, prediction)
#      60     if IOU.shape[0] > 0:
#      61         jaccard = np.max(IOU, axis=0).mean()
#
# ~/nuclei_detection/utils/evaluation.py in intersection_over_union(ground_truth, prediction)
#      10
#      11     # Compute intersection
# ---> 12     h = np.histogram2d(ground_truth.flatten(), prediction.flatten(), bins=(true_objects,pred_objects))
#      13     intersection = h[0]
#      14
#
# <__array_function__ internals> in histogram2d(*args, **kwargs)
#
# ~/.conda/envs/nuclei_detection/lib/python3.7/site-packages/numpy/lib/twodim_base.py in histogram2d(x, y, bins, range, normed, weights, density)
#     713         xedges = yedges = asarray(bins)
#     714         bins = [xedges, yedges]
# --> 715     hist, edges = histogramdd([x, y], bins, range, normed, weights, density)
#     716     return hist, edges[0], edges[1]
#     717
#
# <__array_function__ internals> in histogramdd(*args, **kwargs)
#
# ~/.conda/envs/nuclei_detection/lib/python3.7/site-packages/numpy/lib/histograms.py in histogramdd(sample, bins, range, normed, weights, density)
#    1032         if M != D:
#    1033             raise ValueError(
# -> 1034                 'The dimension of bins must be equal to the dimension of the '
#    1035                 ' sample x.')
#    1036     except TypeError:
#
# ValueError: The dimension of bins must be equal to the dimension of the  sample x.
